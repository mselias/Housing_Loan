# %% [markdown]
# # Importing Libraries

# %%
# System Libraries
import os
import sys

# Database Connector
import pymysql

# Data Manipulator
import pandas as pd
import numpy as np
import random
from sklearn.utils import resample

pd.set_option('display.max_columns', None)

# Data Visualization
import plotly.express as plt
import plotly.graph_objects as go
import seaborn as sns
import matplotlib.pyplot as mplt

# Train/Test Split
from sklearn.model_selection import train_test_split as tts

# Machine Learning: Spectral Clustering, K-Means, Logistic Regression, 
# Random Forest, Neural Network, Extreme Gradient Boosting
from sklearn.cluster import SpectralClustering as sc
from sklearn.cluster import KMeans
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import tensorflow as tf
from tensorflow import keras
import xgboost as xgb

# Machine Learning Metrics
from sklearn import metrics

# Accessory Libraries
import time

# Import custom Library
import CompData as cd

# %% [markdown]
# # Loading Data
#
# ### Setting up for execution

# %%
# Returns the keys and columns for all tables
Columns, Keys = cd.get_table_keys_columns(cd.get_tables())

# Grab columns for Training Data
Application_Column_Tapper_Train = cd.get_core_columns(Columns, 'Application_Train')

# Grab columns for Testing Data
Application_Column_Tapper_Test = cd.get_core_columns(Columns, 'Application_Test')

# %% [markdown]
# ### Executes query to grab final data set
#
# To join the tables, we first need to figure out how we are going to make all the rows unique in the external table prior to the join. As such, we can go ahead and table this to the side first and proceed with the single data set before proceeding. When we decide to join the tables however, there are some complications that we want to consider. One is the Credit Activity Status, and the other is the conversion of the currencies which will allow us to normalize the debt which will grant us to aggregate the information.

# %%
# Grabbing Training Data
train_query = '''SELECT *, 
                        CONCAT(CASE WHEN CNT_CHILDREN > 3 THEN 4
                               ELSE CNT_CHILDREN END,
                               CASE WHEN AMT_CREDIT > 0 AND AMT_CREDIT < 500000 
                                    THEN 1
                                    WHEN AMT_CREDIT > 500000 AND AMT_CREDIT < 1000000 
                                    THEN 2
                                    WHEN AMT_CREDIT > 1000000 AND AMT_CREDIT < 1500000 
                                    THEN 3 ELSE 4 END) AS Partition_Key
                 FROM Application_Train'''
train = cd.get_data(train_query)

# Grabbing Testing Data
test_query = '''SELECT *,
                        CONCAT(CASE WHEN CNT_CHILDREN > 3 THEN 4
                               ELSE CNT_CHILDREN END,
                               CASE WHEN AMT_CREDIT > 0 AND AMT_CREDIT < 500000 
                                    THEN 1
                                    WHEN AMT_CREDIT > 500000 AND AMT_CREDIT < 1000000 
                                    THEN 2
                                    WHEN AMT_CREDIT > 1000000 AND AMT_CREDIT < 1500000 
                                    THEN 3 ELSE 4 END) AS Partition_Key
                FROM Application_Test'''
test = cd.get_data(test_query)
# Out:
# This query took 82.75 seconds to run.
# This query took 12.93 seconds to run.

# %% [markdown]
# # Data Processing
#
# First, we will have to determine the data type and we will figure out how to deal with it here. The method we are going to use here for the continuous variables are as follows:
#
# - **We take a look at where the data is complete**
#
# - **Try two methodologies**
#
#     - **OLS regression** (This method may not be the best way to approach the situation, we will explain this at the end of the test run)
#
#     - **Sampling + Data oscilation and rule-based assignment of values**
#
# This should help us maintain the distribution shape and allow us to process the data better later on in the machine learning phase. For discrete values, we can try the following:
#
# - **To send the missing values far off into the corner**
#
# - **Apply K-Means Clustering Algorithm**
#
# This should help us to tackle the impurities in both the testing and training data sets and will provide us with a good foot hold. Now that we have the potential solutions, we can proceed by first taking a partition of the data set using the table of missing values for the training data. We store the missing value table now for manipulation.
#
# ### Studying Extent of Impurities

# %%
# Gets table of Missing Values for training set
print('''Training Data Metrics:
----------------------''')
missing_train = cd.get_missing(train)
display(missing_train)

# Retreives the columns with missing values for training set
Floats_Train, Objects_Train, Integers_Train = cd.get_missing_partition(missing_train)

# Gets table of Missing Values for testing set
print('''\n\nTesting Data Metrics:
---------------------''')
missing_test = cd.get_missing(test)
display(missing_test)

# Retreives the columns with missing values for testing set
Floats_Test, Objects_Test, Integers_Test = cd.get_missing_partition(missing_test)
# Out:
# Training Data Metrics:
# ----------------------
#                 COMMONAREA_MEDI COMMONAREA_MODE COMMONAREA_AVG  \
# Missing Count            214865          214865         214865
# Missing Percent          69.87%          69.87%         69.87%
# Data Types              float64         float64        float64
#
#                 NONLIVINGAPARTMENTS_MEDI NONLIVINGAPARTMENTS_MODE  \
# Missing Count                     213514                   213514
# Missing Percent                   69.43%                   69.43%
# Data Types                       float64                  float64
#
#                 NONLIVINGAPARTMENTS_AVG FONDKAPREMONT_MODE  \
# Missing Count                    213514             210295
# Missing Percent                  69.43%             68.39%
# Data Types                      float64             object
#
#                 LIVINGAPARTMENTS_MEDI LIVINGAPARTMENTS_MODE  \
# Missing Count                  210199                210199
# ...

# %% [markdown]
# ### Processing Floats Via Method 1: OLS Regression
#
# We will start by testing out method one where we will run an OLS regression to fill in the missing gaps. If needed, we can use a regression tree instead but we will table this for now.
#
# **Note that in our data set, we have a few sets of triplets which signify the Average, Median, and Mode values for a single variable. Doing a quick graph of the three, we were able to see that the distribution of these data points are relatively similar so it would suffice to arbitrarily pick one for the time being to help reduce the number of columns that we will be processing. Once we find a solution to how we want to tackle this, we can then scale up as needed.**

# %%
# Drop all missing values for processing
train_temp_clean = train.dropna()

# This will trim the columns and reduce the number of triplets to only the Averages
Floats_Train_Trimmed = cd.get_core_columns(Floats_Train)
Floats_Train_Trimmed = Floats_Train_Trimmed.split(', ')

# Gather all the float columns in our data set regardless of whether or not they contain missing values
Float_assesment = list(missing_train.T[missing_train.T['Data Types'] == 'float64'].index)

# Grab all the correlation plot columns that we will need
Correlation_plot_columns = cd.get_core_columns(Float_assesment)
Correlation_plot_columns = Correlation_plot_columns.split(', ')

# Partition the data based on the correlation plot columns
correlation_plot_data = train_temp_clean[Correlation_plot_columns]

# %% [markdown]
# Now that the columns have been gathered, let's start by plotting a correlation plot to see how the relationship between the missing values and all the other columns look.

# %%
# Gathering only the non-missing float values
Floats_None_Missing = Correlation_plot_columns
for i in Floats_Train_Trimmed:
    Floats_None_Missing.remove(i)

# Correlation plot
corr = correlation_plot_data.corr()
corr = pd.DataFrame(correlation_plot_data.corr())
corr = corr.loc[Floats_Train_Trimmed,Floats_None_Missing]
# f, ax = mplt.subplots(figsize=(10, 35))
# sns.heatmap(
#     corr, vmin = -1, vmax = 1, center = 0,
#     cmap = sns.diverging_palette(20, 220, n=200),
#     linewidths = 1, square = True, annot = True
# )
# mplt.show()

# For every missing value, grab the column of non-missing values with correlation greater that |0.5|
potential_regressors = {}
for i in Floats_Train_Trimmed:
    
    List_of_regressors = [j for j in corr.loc[i,:].index
                          if (corr.loc[i,j] <= -0.5 or 
                              corr.loc[i,j] >= 0.5) and corr.loc[i,j] != 1]
    if len(List_of_regressors) != 0:
        potential_regressors[i] = List_of_regressors
    else:
        None

potential_regressors

print('''For the missing value columns {0} and {1}, looks like the only potential regressor is 
{2} for both targets.'''.format(list(potential_regressors.keys())[0],
                                list(potential_regressors.keys())[1],
                                list(potential_regressors.values())[0][0]))
# Out:
# For the missing value columns AMT_GOODS_PRICE and AMT_ANNUITY, looks like the only potential regressor is
# AMT_CREDIT for both targets.

# %% [markdown]
# Annnnnnnnnd drumroll please!!!!!!!! Looks like this method will not work. The main reason for this is two fold. First, we do not have an ample amount of clean continuous variables to run the process **(Although... we could look at the other variables as well to see if this will help, lets table this for now).** Second, from the variables that do not contain missing values, they yeild very low correlations. As such, instead of continuing with attempting method 1, we will try method 2 instead.
#
# ### Processing Floats Via Method 2: Sampling/Oscilation/Rule-Base Assignment
#
# Continuing from part one, we will look only at the non-misisng data and begin by partitioning the data by some criteria.
#
# **Do note that we do not want to create a partition so small that the set is empty. To avoid this, let's think about some of the important criteria that make up a given missing value columns.**
#
# Let's start by spliting some of the missing data systimatically within each of their data types. To do this, let's start with the Float varaibles. It is clear that the data falls into the following category types:
#
# - Current Home Attributes Of Client
# - Credit/Bureau Attributes
# - Personal Attributes
#
# With this information, what we essentially want to do is to understand from the columns with no missing information, how we can better split the data sets. After which, from within each of the sub partitions we want to sample, and take away some sort of variation away from the mean. In particular, since the values are between {0, 1} we will be using the squared distance to randomly oscilate the data point.

# %%
Categorization = {}
CHA = []
CA = []
PA = []

for i in Floats_Train_Trimmed:
    if '_AVG' in i:
        CHA.append(i)
        Categorization['Current_Home_Attributes'] = CHA
    elif '_CREDIT_' in i:
        CA.append(i)
        Categorization['Credit_Attributes'] = CA
    else:
        PA.append(i)
        Categorization['Personal_Attributes'] = PA

# %% [markdown]
# Randomization will occur as follows:
#
# - Using the categorizations, we will first begin by paritioning on that
#     - One thing we want to figure out is if when we partition the data, do we want to use different partition keys for each of the categorizations above. For now, we have just applied the same data partitioning key to all the floats with missing values but this may change later on once we attempt to fit a model
#
# - After which, we will then split the data within each grouping, we take the key and then fill the values in from there
#
# ### Processing: Train

# %%
# Set up timer
Start = time.perf_counter()

# Partitions data and stores it as a dictionary
Data_Partitions_Train = {}
for i in set(train.Partition_Key):
    Data_Partitions_Train[i] = train[train.Partition_Key == i].copy()

# This cleans the missing data frames within the dictionary list
for j in Data_Partitions_Train.keys():
    for i in Categorization['Current_Home_Attributes']:
        Partition = Data_Partitions_Train[j]
        Partition.loc[Partition[i].isnull() == True, i] = cd.fill_missing(Partition, i)

# This cleans the missing data frames within the dictionary list
for j in Data_Partitions_Train.keys():
    for i in Categorization['Credit_Attributes']:
        Partition = Data_Partitions_Train[j]
        Partition.loc[Partition[i].isnull() == True, i] = [int(i) for i in cd.fill_missing(Partition, i)]
        
# This cleans the missing data frames within the dictionary list
for j in Data_Partitions_Train.keys():
    for i in Categorization['Personal_Attributes']:
        Partition = Data_Partitions_Train[j]
        Partition.loc[Partition[i].isnull() == True, i] = [int(i) for i in cd.fill_missing(Partition, i)]

# Cleaned training data is compiled and stores as train_cleaned_floats
train_cleaned_floats = pd.concat(list(Data_Partitions_Train.values()))

# Looks at only the important columns
truncated_columns = cd.get_core_columns(train_cleaned_floats.columns)
train_cleaned_floats = train_cleaned_floats[truncated_columns.split(', ')]

# Ends timer and returns time taken to execute process
End = time.perf_counter()
print('The data cleaning process took {0} seconds to complete.'.format(round(End - Start, 2)))
# Out:
# The data cleaning process took 12.74 seconds to complete.

# %% [markdown]
# ### Processing: Test

# %%
# Set up timer
Start = time.perf_counter()

# Partitions data and stores it as a dictionary
Data_Partitions_Test = {}
for i in set(test.Partition_Key):
    Data_Partitions_Test[i] = test[test.Partition_Key == i].copy()

# This cleans the missing data frames within the dictionary list
for j in Data_Partitions_Test.keys():
    for i in Categorization['Current_Home_Attributes']:
        Partition = Data_Partitions_Test[j]
        Partition.loc[Partition[i].isnull() == True, i] = cd.fill_missing(Partition, i)

# This cleans the missing data frames within the dictionary list
for j in Data_Partitions_Test.keys():
    for i in Categorization['Credit_Attributes']:
        Partition = Data_Partitions_Test[j]
        Partition.loc[Partition[i].isnull() == True, i] = [int(i) for i in cd.fill_missing(Partition, i)]
        
# This cleans the missing data frames within the dictionary list
for j in Data_Partitions_Test.keys():
    for i in Categorization['Personal_Attributes']:
        Partition = Data_Partitions_Test[j]
        Partition.loc[Partition[i].isnull() == True, i] = [int(i) for i in cd.fill_missing(Partition, i)]

# Cleaned testing data is compiled and stores as test_cleaned_floats
test_cleaned_floats = pd.concat(list(Data_Partitions_Test.values()))

# Looks at only the important columns
truncated_columns = cd.get_core_columns(test_cleaned_floats.columns)
test_cleaned_floats = test_cleaned_floats[truncated_columns.split(', ')]

# Ends timer and returns time taken to execute process
End = time.perf_counter()
print('The data cleaning process took {0} seconds to complete.'.format(round(End - Start, 2)))
# Out:
# The data cleaning process took 3.8 seconds to complete.

# %% [markdown]
# Method 2 looks to be working well! The values that were missing were filled successfully, and the distribution of the data points were maintained. As such, we can go ahead and continue with treating the missing Categorical Values and take one last look at the data set, treat any imbalances and proceed with the machine learning process.
#
# ### Processing Objects: K-Means Clustering
#
# Before we proceed, let's look at a few things that we want to see from our data. First, we want to analysis our data set a little more to understand if there is seperability. By this, what we are referring to is a clear path that indicates that the data is split apart from one another into classes. If this is the case, a simple K-Means will work. Second, if we find that this is not immediately apparent, we may need to further our analysis by getting a little creative with the solution. What we mean by this is suppose that the data set is not seperable, there may be a need to explore Kernal based methods such as Spectral Clustering. Currently, the following has been done:
#
# - K-Means clustering
#
#     - Issue is that the data set is overlapping a great deal
#
# - Potential solution is to use Kernal based Spectral Clustering
#
#     - Understanding method mathematically and then appying this to our theory
#
# From some analysis, we note that K-Means does not work well and will not be the best approach to our problem. We proceed by looking at Spectral Clustering.

# %%
X = train_cleaned_floats[['OWN_CAR_AGE', 'CNT_FAM_MEMBERS', 'OBS_60_CNT_SOCIAL_CIRCLE', 'OCCUPATION_TYPE']]
X = X.dropna()

#plt.scatter_3d(data_frame = X, y = 'OWN_CAR_AGE', x = 'OBS_60_CNT_SOCIAL_CIRCLE', 
#               z = 'CNT_FAM_MEMBERS', color = 'OCCUPATION_TYPE')

# %%
X = train_cleaned_floats[['AMT_CREDIT', 'OWN_CAR_AGE', 'CNT_FAM_MEMBERS']]
X = X.dropna()
within_cluster_sum_of_squares = []
for i in range(1, 19):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 100)
    kmeans.fit(X)
    # inertia method returns wcss for that model
    within_cluster_sum_of_squares.append(kmeans.inertia_)

mplt.figure(figsize=(10,5))
sns.lineplot(range(1, 19), within_cluster_sum_of_squares, marker='o', color='red')
mplt.title('The Elbow Method')
mplt.xlabel('Number of clusters')
mplt.ylabel('WCSS')
mplt.show()

# %% [markdown]
# Spectral Clustering is having some memory issues. Two options that we could explore. The first, we can try and build this module from scratch and have this function faster in comparison to Sci-Kit Learn's module. The second route we can take is to load this into a Spark environment and use that to run the operation.
#
# Let's try Spark first and then we can explore the other option. Once we have that in place, we can execute the solution and move forward. This however may take some time, we will just drop the Object columns for now and return to this later.

# %%
# X = train_cleaned_floats[['AMT_CREDIT', 'OWN_CAR_AGE', 'CNT_FAM_MEMBERS']]
# cluster = sc(n_clusters = 18, random_state = 50, n_init = 20, assign_labels = 'discretize')
# fitted = cluster.fit(X)

# %% [markdown]
# ### Assessing Class Imbalance
#
# Now that our data set has been processed, let's go ahead and start looking at our target and fix any imbalances that are occurring. Once that has been done, we will go ahead and try a few algorithms out and test the accuracy, precision, and recall. After which, we will decide what to do moving forward and go from there!

# %%
clean_trained = train_cleaned_floats.copy()

total = len(clean_trained)
positive_target = (clean_trained.TARGET == 1).sum()
negative_target = (clean_trained.TARGET == 0).sum()

print('{0}% of the data set consists of 1s and {1}% are 0s'.format(round((positive_target*100)/total, 2), 
                                                                   round((negative_target*100)/total, 2)))
# Out:
# 8.07% of the data set consists of 1s and 91.93% are 0s

# %% [markdown]
# YIKES!!! That is horrible... The imbalance is really bad, thus we need to figure out a way to fix this issue. There are two methods we can try which are up-sampling or down-sampling. We start by down-sampling and then proceed to the Machine Learning phase.

# %%
clean_trained = clean_trained.drop(columns = ['OCCUPATION_TYPE', 'NAME_TYPE_SUITE'])
type_cleaned = cd.get_missing(clean_trained)

transformation_columns = list(type_cleaned.T[type_cleaned.T['Data Types'] == 'object'].index)
other_columns = list(type_cleaned.T[type_cleaned.T['Data Types'] != 'object'].index)
other_columns.remove('TARGET')

y = clean_trained.TARGET
X = clean_trained[other_columns]

X_train, X_test, y_train, y_test = tts(X, y, test_size = 0.20, random_state = 0)

cleaned_train_data_joined = pd.concat([X_train, y_train], axis = 1, join='inner')

majority = cleaned_train_data_joined[cleaned_train_data_joined.TARGET == 0]
minority = cleaned_train_data_joined[cleaned_train_data_joined.TARGET == 1]

down_sampled = resample(majority, replace = False, 
                        n_samples = len(minority),
                        random_state = 1)

up_sampled = resample(minority, replace = True, 
                      n_samples = len(majority),
                      random_state = 1)

cleaned_balanced = pd.concat([majority, up_sampled])

# cleaned_balanced = pd.concat([minority, down_sampled])

X_train = cleaned_balanced[other_columns]
y_train = cleaned_balanced.TARGET

# %% [markdown]
# The data is now balanced and we can proceed with the next steps! If down-sampling does not yeild good results, we will return back here and do up-sampling instead.
#
# # Model Building
#
# We are now at the Machine Learning phase! :) For this particular step, we will try out 3 different models. These models are the classic Logistic Regression, Random Forest, and Support Vector Machines. Going through these models, we will keep an eye out for the accuracy, precision, and recall provided by these models. Once that has been assessed, if they are not satisfactory we have a few options:
#
# 1) We could attempt to model this using a Neural Network
# 2) We can enrich the data set with more features drawn in from the remaining data and rerun the process again
#
# Without futher pause, we will proceed with my favorite portion!
#
# ### Logistic Regression

# %%
glm = LogisticRegression(fit_intercept = True, solver = 'lbfgs', max_iter = 500).fit(X_train, y_train)

print('Accuracy: {0}%'.format(round(metrics.accuracy_score(y_test, 
                                                           glm.predict(X_test))*100, 2)))
print('AUC Score: {0}\n'.format(round(metrics.roc_auc_score(y_test, 
                                                            glm.predict(X_test)), 2)))

print(metrics.classification_report(y_test, glm.predict(X_test)))
# Out:
# Accuracy: 59.31%
# AUC Score: 0.59
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.59      0.73     56514
#            1       0.11      0.58      0.19      4989
#
#    micro avg       0.59      0.59      0.59     61503
#    macro avg       0.53      0.59      0.46     61503
# weighted avg       0.87      0.59      0.68     61503

# %% [markdown]
# ### Random Forest

# %%
Random_Forest = RandomForestClassifier(max_depth = 10, random_state = 0,
                                       criterion = 'entropy', n_estimators = 25).fit(X_train, y_train)

print('Accuracy: {0}%'.format(round(metrics.accuracy_score(y_test, 
                                                           Random_Forest.predict(X_test))*100, 2)))
print('AUC Score: {0}\n'.format(round(metrics.roc_auc_score(y_test, 
                                                            Random_Forest.predict(X_test)), 2)))

print(metrics.classification_report(y_test, Random_Forest.predict(X_test)))
# Out:
# Accuracy: 69.6%
# AUC Score: 0.66
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.70      0.81     56514
#            1       0.16      0.62      0.25      4989
#
#    micro avg       0.70      0.70      0.70     61503
#    macro avg       0.56      0.66      0.53     61503
# weighted avg       0.89      0.70      0.76     61503

# %% [markdown]
# ### Extreme Gradient Boosting Classifier

# %%
XGBC = xgb.XGBClassifier(objective = 'binary:logistic', learning_rate = 0.001,
                         gamma = 0, subsample = 0.8).fit(X_train, y_train)

print('Accuracy: {0}%'.format(round(metrics.accuracy_score(y_test, 
                                                           XGBC.predict(X_test))*100, 2)))
print('AUC Score: {0}\n'.format(round(metrics.roc_auc_score(y_test, 
                                                            XGBC.predict(X_test)), 2)))

print(metrics.classification_report(y_test, XGBC.predict(X_test)))### Extreme Gradient Boosting Classifier
# Out:
# Accuracy: 66.03%
# AUC Score: 0.66
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.66      0.78     56514
#            1       0.15      0.65      0.24      4989
#
#    micro avg       0.66      0.66      0.66     61503
#    macro avg       0.55      0.66      0.51     61503
# weighted avg       0.89      0.66      0.74     61503

# %% [markdown]
# ### Extreme Gradient Boosting Random Forest Classifier

# %%
XGBRFC = xgb.XGBRFClassifier(booster = 'dart', objective = 'binary:logistic', max_depth = 10, 
                             learning_rate = 0.0001, gamma = 0.001, subsample = 0.48, verbosity = 1,
                             num_parallel_tree = 100, tree_method = 'approx', 
                             normalize_type = 'forest', colsample_bytree = 0.5).fit(X_train, y_train)

print('Accuracy: {0}%'.format(round(metrics.accuracy_score(y_test, 
                                                           XGBRFC.predict(X_test))*100, 2)))
print('AUC Score: {0}\n'.format(round(metrics.roc_auc_score(y_test, 
                                                            XGBRFC.predict(X_test)), 2)))

print(metrics.classification_report(y_test, XGBRFC.predict(X_test)))
# Out:
# Accuracy: 72.6%
# AUC Score: 0.67
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.74      0.83     56514
#            1       0.17      0.60      0.26      4989
#
#    micro avg       0.73      0.73      0.73     61503
#    macro avg       0.56      0.67      0.55     61503
# weighted avg       0.89      0.73      0.79     61503

# %% [markdown]
# ### Neural Network

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape = (len(X_train.columns),)),
    keras.layers.Dense(10, activation = tf.nn.leaky_relu),
    keras.layers.Dense(20, activation = tf.nn.sigmoid),
    keras.layers.Dense(1, activation = tf.nn.tanh)
])

model.compile(optimizer = 'sgd',
              loss = 'binary_crossentropy',
              metrics = ['accuracy'])

model.fit(X_train, y_train, epochs = 8, batch_size = 10)
test_loss, test_acc = model.evaluate(X_test, y_test)
print('\n\nTesting Loss: {0} \nTesting Accuracy: {1}%\n\n'.format(test_loss,
                                                                  round(test_acc*100, 2)))

pred = []
for i in model.predict_classes(X_test):
    pred.append(i[0])

print('Accuracy: {0}%'.format(round(metrics.accuracy_score(y_test, pred)*100, 2)))
print('AUC Score: {0}\n'.format(round(metrics.roc_auc_score(y_test, pred), 2)))

print(metrics.classification_report(y_test, pred))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/8
# 452344/452344 [==============================] - 73s 161us/sample - loss: 0.7072 - acc: 0.5001
# Epoch 2/8
# 452344/452344 [==============================] - 72s 159us/sample - loss: 0.6995 - acc: 0.5006
# Epoch 3/8
# 452344/452344 [==============================] - 71s 157us/sample - loss: 0.6995 - acc: 0.5003
# Epoch 4/8
# 452344/452344 [==============================] - 71s 157us/sample - loss: 0.6993 - acc: 0.5008
# ...

# %% [markdown]
# After running a few models, we have found that the model providing the best result is the XGBoost Random Forest model! That being said however, the Accuracy is sitting at roughly 70% with an AUC Score of 0.67 which is still a little low. As such, we will go ahead and return back to the Data Processing step to enrich the data set and clean it once again :) After which, we will go ahead and re-run the models with the new enriched data and evaluate the results again!
#
# # Deployment
#
# Currently put on pause!
